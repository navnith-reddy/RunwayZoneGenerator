# %%
import runwayZoneGenerator as rzg
import pandas as pd

# Initialise runway centreline dataset
rzg.buildRunways()
runways = rzg.readRunways()

# Sydney Dataset
sydney = runways.loc[runways['NAME'] == 'SYDNEY AIRPORT']
sydney.reset_index(drop=True, inplace=True)

# Canberra Dataset
canberra = runways.loc[runways['NAME'] == 'CANBERRA AIRPORT']
canberra.reset_index(drop=True, inplace=True)

# Canberra Dataset
melbourne = runways.loc[runways['NAME'] == 'MELBOURNE AIRPORT']
melbourne.reset_index(drop=True, inplace=True)

# Canberra Dataset
perth = runways.loc[runways['NAME'] == 'PERTH INTERNATIONAL AIRPORT']
perth.reset_index(drop=True, inplace=True)

# %%
# Initialise empty list of naming variables
name = []

# Initialise lists for other data
location = ['Sydney'] * 12
identifier = ['YSSY'] * 12

# Retrieve runway centreline geometry from dataset
rwcl16l = sydney.at[0, 'geometry']
# Create zone geometries
rw16l = rzg.asymmetricZones(rwcl16l, side=1)
# Create naming variables
name.extend(['16L']*3)

# Repeat steps above, but with welded runways
# Step not required for datasets without bisected runways
rwcl16r = rzg.weldRunways(sydney.at[1, 'geometry'], sydney.at[2, 'geometry'])
rw16r = rzg.asymmetricZones(rwcl16r, side=1)
name.extend(['16R']*3)

rw34r = rzg.asymmetricZones(rwcl16l, side=0)
name.extend(['34R']*3)

rw34l = rzg.asymmetricZones(rwcl16r, side=0)
name.extend(['34L']*3)

# Merge runways and add columns
sydRunways = rw16l.append(rw16r, ignore_index=True)
sydRunways = sydRunways.append(rw34r, ignore_index=True)
sydRunways = sydRunways.append(rw34l, ignore_index=True)
sydRunways['Location'] = location
sydRunways['Identifier'] = identifier
sydRunways['Runway'] = name
sydRunways.explore()
# Out:
# C:\Users\navni\AppData\Local\Temp\ipykernel_6084\1947642251.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sydRunways = rw16l.append(rw16r, ignore_index=True)
# C:\Users\navni\AppData\Local\Temp\ipykernel_6084\1947642251.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sydRunways = sydRunways.append(rw34r, ignore_index=True)
# C:\Users\navni\AppData\Local\Temp\ipykernel_6084\1947642251.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sydRunways = sydRunways.append(rw34l, ignore_index=True)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_15f134df26a6098a3719305b1bf1d719 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_15f134df26a6098a3719305b1bf1d719&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_15f134df26a6098a3719305b1bf1d719 = L.map(
#                 &quot;map_15f134df26a6098a3719305b1bf1d719&quot;,
#                 {
#                     center: [-33.949290364461774, 151.18222313223384],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_15f134df26a6098a3719305b1bf1d719);
#
#
#
#
#
#             var tile_layer_ee6d55e085c8e0437367859a41f7afba = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_15f134df26a6098a3719305b1bf1d719);
#
#
#             map_15f134df26a6098a3719305b1bf1d719.fitBounds(
#                 [[-34.03125787827621, 151.1497474238687], [-33.86732285064734, 151.214698840599]],
#                 {}
#             );
#
#
#         function geo_json_80b28537c7fe12894d8f6bb44b6a8ca0_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_80b28537c7fe12894d8f6bb44b6a8ca0_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_80b28537c7fe12894d8f6bb44b6a8ca0_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_80b28537c7fe12894d8f6bb44b6a8ca0_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_80b28537c7fe12894d8f6bb44b6a8ca0_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_80b28537c7fe12894d8f6bb44b6a8ca0.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_80b28537c7fe12894d8f6bb44b6a8ca0_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_80b28537c7fe12894d8f6bb44b6a8ca0 = L.geoJson(null, {
#                 onEachFeature: geo_json_80b28537c7fe12894d8f6bb44b6a8ca0_onEachFeature,
#
#                 style: geo_json_80b28537c7fe12894d8f6bb44b6a8ca0_styler,
#                 pointToLayer: geo_json_80b28537c7fe12894d8f6bb44b6a8ca0_pointToLayer
#         });
#
#         function geo_json_80b28537c7fe12894d8f6bb44b6a8ca0_add (data) {
#             geo_json_80b28537c7fe12894d8f6bb44b6a8ca0
#                 .addData(data)
#                 .addTo(map_15f134df26a6098a3719305b1bf1d719);
#         }
#             geo_json_80b28537c7fe12894d8f6bb44b6a8ca0_add({&quot;bbox&quot;: [151.1497474238687, -34.03125787827621, 151.214698840599, -33.86732285064734], &quot;features&quot;: [{&quot;bbox&quot;: [151.1882354219853, -33.97101731525299, 151.19379541829747, -33.9495173145839], &quot;geometry&quot;: {&quot;coordinates&quot;: [[151.1882354219853, -33.9495173145839], [151.19379541829747, -33.97101731525299]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;Identifier&quot;: &quot;YSSY&quot;, &quot;Location&quot;: &quot;Sydney&quot;, &quot;Polygon Name&quot;: &quot;Runway&quot;, &quot;Runway&quot;: &quot;16L&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [151.16733199968374, -33.98658599151822, 151.21256995115425, -33.925706685482396],

# %%
name = []
location = ['Perth'] * 6
identifier = ['YPPH'] * 6

rwcl03 = rzg.weldRunways(perth.at[2, 'geometry'], perth.at[4, 'geometry'])
rw03 = rzg.asymmetricZones(rwcl03, side=1)
name.extend(['03']*3)

rw21 = rzg.asymmetricZones(rwcl03, side=0)
name.extend(['21']*3)

# Merge runways and add columns
perthRunways = rw03.append(rw21, ignore_index=True)
perthRunways['Location'] = location
perthRunways['Identifier'] = identifier
perthRunways['Runway'] = name
perthRunways.explore()
# Out:
# C:\Users\navni\AppData\Local\Temp\ipykernel_6084\967405513.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   perthRunways = rw03.append(rw21, ignore_index=True)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4d1648912d15435be675b17f06fc1391 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4d1648912d15435be675b17f06fc1391&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4d1648912d15435be675b17f06fc1391 = L.map(
#                 &quot;map_4d1648912d15435be675b17f06fc1391&quot;,
#                 {
#                     center: [-31.943660334673947, 115.96404446963226],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_4d1648912d15435be675b17f06fc1391);
#
#
#
#
#
#             var tile_layer_68aa8d1e93bed56443245c2130a40336 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4d1648912d15435be675b17f06fc1391);
#
#
#             map_4d1648912d15435be675b17f06fc1391.fitBounds(
#                 [[-32.01999060754021, 115.93795762770512], [-31.867330061807685, 115.9901313115594]],
#                 {}
#             );
#
#
#         function geo_json_58e6aec69929c57b2ca76eaa4f39f2fe_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_58e6aec69929c57b2ca76eaa4f39f2fe_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_58e6aec69929c57b2ca76eaa4f39f2fe_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_58e6aec69929c57b2ca76eaa4f39f2fe_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_58e6aec69929c57b2ca76eaa4f39f2fe_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_58e6aec69929c57b2ca76eaa4f39f2fe.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_58e6aec69929c57b2ca76eaa4f39f2fe_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_58e6aec69929c57b2ca76eaa4f39f2fe = L.geoJson(null, {
#                 onEachFeature: geo_json_58e6aec69929c57b2ca76eaa4f39f2fe_onEachFeature,
#
#                 style: geo_json_58e6aec69929c57b2ca76eaa4f39f2fe_styler,
#                 pointToLayer: geo_json_58e6aec69929c57b2ca76eaa4f39f2fe_pointToLayer
#         });
#
#         function geo_json_58e6aec69929c57b2ca76eaa4f39f2fe_add (data) {
#             geo_json_58e6aec69929c57b2ca76eaa4f39f2fe
#                 .addData(data)
#                 .addTo(map_4d1648912d15435be675b17f06fc1391);
#         }
#             geo_json_58e6aec69929c57b2ca76eaa4f39f2fe_add({&quot;bbox&quot;: [115.93795762770512, -32.01999060754021, 115.9901313115594, -31.867330061807685], &quot;features&quot;: [{&quot;bbox&quot;: [115.95960069182922, -31.958756600527426, 115.96849068828976, -31.928626599907496], &quot;geometry&quot;: {&quot;coordinates&quot;: [[115.95960069182922, -31.958756600527426], [115.96588068932728, -31.937456600089416], [115.96849068828976, -31.928626599907496]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;Identifier&quot;: &quot;YPPH&quot;, &quot;Location&quot;: &quot;Perth&quot;, &quot;Polygon Name&quot;: &quot;Runway&quot;, &quot;Runway&quot;: &quot;03&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [115.93795762770512, -31.983

# %%
name = []
location = ['Canberra'] * 3
identifier = ['YSCB'] * 3

rwcl35 = rzg.weldRunways(canberra.at[0, 'geometry'], canberra.at[3, 'geometry'])
rw35 = rzg.zoneConstructor(rwcl35)
name.extend(['35']*3)

cbrRunways = rw35
cbrRunways['Location'] = location
cbrRunways['Identifier'] = identifier
cbrRunways['Runway'] = name
cbrRunways.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7fb6dc3e890ecfc3605e995ab54bdf18 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7fb6dc3e890ecfc3605e995ab54bdf18&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7fb6dc3e890ecfc3605e995ab54bdf18 = L.map(
#                 &quot;map_7fb6dc3e890ecfc3605e995ab54bdf18&quot;,
#                 {
#                     center: [-35.30287987034764, 149.19482054014557],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_7fb6dc3e890ecfc3605e995ab54bdf18);
#
#
#
#
#
#             var tile_layer_29d218c4febd86f29470db5969ac539d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7fb6dc3e890ecfc3605e995ab54bdf18);
#
#
#             map_7fb6dc3e890ecfc3605e995ab54bdf18.fitBounds(
#                 [[-35.375571499752056, 149.17899676342256], [-35.230188240943214, 149.21064431686858]],
#                 {}
#             );
#
#
#         function geo_json_181214a4f3e501d1d11aae63cafa9be7_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_181214a4f3e501d1d11aae63cafa9be7_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_181214a4f3e501d1d11aae63cafa9be7_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_181214a4f3e501d1d11aae63cafa9be7_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_181214a4f3e501d1d11aae63cafa9be7_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_181214a4f3e501d1d11aae63cafa9be7.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_181214a4f3e501d1d11aae63cafa9be7_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_181214a4f3e501d1d11aae63cafa9be7 = L.geoJson(null, {
#                 onEachFeature: geo_json_181214a4f3e501d1d11aae63cafa9be7_onEachFeature,
#
#                 style: geo_json_181214a4f3e501d1d11aae63cafa9be7_styler,
#                 pointToLayer: geo_json_181214a4f3e501d1d11aae63cafa9be7_pointToLayer
#         });
#
#         function geo_json_181214a4f3e501d1d11aae63cafa9be7_add (data) {
#             geo_json_181214a4f3e501d1d11aae63cafa9be7
#                 .addData(data)
#                 .addTo(map_7fb6dc3e890ecfc3605e995ab54bdf18);
#         }
#             geo_json_181214a4f3e501d1d11aae63cafa9be7_add({&quot;bbox&quot;: [149.17899676342256, -35.375571499752056, 149.21064431686858, -35.230188240943214], &quot;features&quot;: [{&quot;bbox&quot;: [149.19481553946355, -35.31548714580709, 149.19482554265846, -35.29033714563862], &quot;geometry&quot;: {&quot;coordinates&quot;: [[149.19481553946355, -35.31548714580709], [149.1948155405047, -35.307297145751946], [149.19482554265846, -35.29033714563862]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;Identifier&quot;: &quot;YSCB&quot;, &quot;Location&quot;: &quot;Canberra&quot;, &quot;Polygon Name&quot;: &quot;Runway Centreline&quot;, &quot;Runway&quot;: &quot;35&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [149.17899676342

# %%
name = []
location = ['Melbourne'] * 3
identifier = ['YMML'] * 3

rwcl16 = rzg.weldRunways(melbourne.at[0, 'geometry'], melbourne.at[3, 'geometry'])
rw16 = rzg.zoneConstructor(rwcl16)
name.extend(['16']*3)

melbRunways = rw16
melbRunways['Location'] = location
melbRunways['Identifier'] = identifier
melbRunways['Runway'] = name
melbRunways.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_49fff505e9a2d95bb1ab9667ff9c6432 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_49fff505e9a2d95bb1ab9667ff9c6432&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_49fff505e9a2d95bb1ab9667ff9c6432 = L.map(
#                 &quot;map_49fff505e9a2d95bb1ab9667ff9c6432&quot;,
#                 {
#                     center: [-37.66946497620854, 144.8382872554946],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_49fff505e9a2d95bb1ab9667ff9c6432);
#
#
#
#
#
#             var tile_layer_c5ff5d2ae780fefb7bc2c42f653408b2 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_49fff505e9a2d95bb1ab9667ff9c6432);
#
#
#             map_49fff505e9a2d95bb1ab9667ff9c6432.fitBounds(
#                 [[-37.743900596753605, 144.81583514991394], [-37.59502935566347, 144.86073936107525]],
#                 {}
#             );
#
#
#         function geo_json_b677fba0379f4cb2c62228769097ffb8_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_b677fba0379f4cb2c62228769097ffb8_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_b677fba0379f4cb2c62228769097ffb8_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_b677fba0379f4cb2c62228769097ffb8_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_b677fba0379f4cb2c62228769097ffb8_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_b677fba0379f4cb2c62228769097ffb8.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_b677fba0379f4cb2c62228769097ffb8_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_b677fba0379f4cb2c62228769097ffb8 = L.geoJson(null, {
#                 onEachFeature: geo_json_b677fba0379f4cb2c62228769097ffb8_onEachFeature,
#
#                 style: geo_json_b677fba0379f4cb2c62228769097ffb8_styler,
#                 pointToLayer: geo_json_b677fba0379f4cb2c62228769097ffb8_pointToLayer
#         });
#
#         function geo_json_b677fba0379f4cb2c62228769097ffb8_add (data) {
#             geo_json_b677fba0379f4cb2c62228769097ffb8
#                 .addData(data)
#                 .addTo(map_49fff505e9a2d95bb1ab9667ff9c6432);
#         }
#             geo_json_b677fba0379f4cb2c62228769097ffb8_add({&quot;bbox&quot;: [144.81583514991394, -37.743900596753605, 144.86073936107525, -37.59502935566347], &quot;features&quot;: [{&quot;bbox&quot;: [144.8352459761409, -37.68589682741093, 144.84132597156997, -37.65310682679493], &quot;geometry&quot;: {&quot;coordinates&quot;: [[144.84132597156997, -37.68589682741093], [144.83681597496616, -37.661526826953704], [144.8352459761409, -37.65310682679493]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;Identifier&quot;: &quot;YMML&quot;, &quot;Location&quot;: &quot;Melbourne&quot;, &quot;Polygon Name&quot;: &quot;Runway Centreline&quot;, &quot;Runway&quot;: &quot;16&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [144.81583514991394

# %%
runways = sydRunways.append(cbrRunways, ignore_index=True)
runways = runways.append(melbRunways, ignore_index=True)
runways = runways.append(perthRunways, ignore_index=True)
runways.to_file('study/study.shp')
runways.explore()
# Out:
# C:\Users\navni\AppData\Local\Temp\ipykernel_6084\3992338262.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   runways = sydRunways.append(cbrRunways, ignore_index=True)
# C:\Users\navni\AppData\Local\Temp\ipykernel_6084\3992338262.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   runways = runways.append(melbRunways, ignore_index=True)
# C:\Users\navni\AppData\Local\Temp\ipykernel_6084\3992338262.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   runways = runways.append(perthRunways, ignore_index=True)
# C:\Users\navni\AppData\Local\Temp\ipykernel_6084\3992338262.py:4: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   runways.to_file('study/study.shp')
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_29b700501651324b52290f125893886c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_29b700501651324b52290f125893886c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_29b700501651324b52290f125893886c = L.map(
#                 &quot;map_29b700501651324b52290f125893886c&quot;,
#                 {
#                     center: [-34.80561532928064, 133.57632823415207],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_29b700501651324b52290f125893886c);
#
#
#
#
#
#             var tile_layer_c1acc4be9c8c3ca23defa0d4428b5cb1 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_29b700501651324b52290f125893886c);
#
#
#             map_29b700501651324b52290f125893886c.fitBounds(
#                 [[-37.743900596753605, 115.93795762770512], [-31.867330061807685, 151.214698840599]],
#                 {}
#             );
#
#
#         function geo_json_18e10a295b8841724972bf26b64c6b0d_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_18e10a295b8841724972bf26b64c6b0d_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_18e10a295b8841724972bf26b64c6b0d_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_18e10a295b8841724972bf26b64c6b0d_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_18e10a295b8841724972bf26b64c6b0d_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_18e10a295b8841724972bf26b64c6b0d.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_18e10a295b8841724972bf26b64c6b0d_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_18e10a295b8841724972bf26b64c6b0d = L.geoJson(null, {
#                 onEachFeature: geo_json_18e10a295b8841724972bf26b64c6b0d_onEachFeature,
#
#                 style: geo_json_18e10a295b8841724972bf26b64c6b0d_styler,
#                 pointToLayer: geo_json_18e10a295b8841724972bf26b64c6b0d_pointToLayer
#         });
#
#         function geo_json_18e10a295b8841724972bf26b64c6b0d_add (data) {
#             geo_json_18e10a295b8841724972bf26b64c6b0d
#                 .addData(data)
#                 .addTo(map_29b700501651324b52290f125893886c);
#         }
#             geo_json_18e10a295b8841724972bf26b64c6b0d_add({&quot;bbox&quot;: [115.93795762770512, -37.743900596753605, 151.214698840599, -31.867330061807685], &quot;features&quot;: [{&quot;bbox&quot;: [151.1882354219853, -33.97101731525299, 151.19379541829747, -33.9495173145839], &quot;geometry&quot;: {&quot;coordinates&quot;: [[151.1882354219853, -33.9495173145839], [151.19379541829747, -33.97101731525299]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;Identifier&quot;: &quot;YSSY&quot;, &quot;Location&quot;: &quot;Sydney&quot;, &quot;Polygon Name&quot;: &quot;Runway&quot;, &quot;Runway&quot;: &quot;16L&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [151.16733199968374, -33.98658599151822, 151.21256995115425, -33.9257066854823
